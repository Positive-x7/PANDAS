# %%
import pandas as pd
df = pd.read_csv('StudentsPerformance.csv')
# Out:
# C:\Users\Algo1c14\AppData\Local\Temp\ipykernel_9056\3839773949.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df['gender'].value_counts().plot(kind = 'barh', grid=True)
# Out:
# <Axes: ylabel='gender'>

# %%
df['race/ethnicity'].value_counts().plot(kind = 'barh', grid=True)
# Out:
# <Axes: ylabel='race/ethnicity'>

# %%
df['parental level of education'].value_counts().plot(kind = 'barh', grid=True)
# Out:
# <Axes: ylabel='parental level of education'>

# %%
print(df['math score'].agg(['min', 'mean', 'max']))
# Out:
# min       0.000
# mean     66.089
# max     100.000
# Name: math score, dtype: float64
